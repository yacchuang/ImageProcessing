# %%
# !pip install imagecodecs
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ya-chen.chuang\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ya-chen.chuang\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ya-chen.chuang\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ya-chen.chuang\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ya-chen.chuang\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ya-chen.chuang\anaconda3\lib\site-packages)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from tifffile import imread, imsave
from csbdeep.utils import Path, normalize
from csbdeep.utils.tf import keras_import
keras = keras_import()

from stardist import export_imagej_rois, random_label_cmap
from stardist.models import StarDist2D

np.random.seed(0)
cmap = random_label_cmap()

# %%
def show_image(img, **kwargs):
    """Plot large image at different resolutions."""
    fig, ax = plt.subplots(2,4, figsize=(16,8))
    mid = [s//2 + 600 for s in img.shape[:2]]
    for a,t,u in zip(ax.ravel(),[1,2,4,8,16,32,64,128],[16,8,4,2,1,1,1,1]):
        sl = tuple(slice(c - s//t//2, c + s//t//2, u) for s,c in zip(img.shape[:2],mid))
        a.imshow(img[sl], **kwargs)
        a.axis('off')
    plt.tight_layout()
    plt.show()

# %%
img = imread('C:/Users/ya-chen.chuang/Documents/QuPath/validation/QuPathValidationImages/SP-014200_1501-1F-CS-DRG1_EGFP-C1_mCherry-C2_MfaRBFOX3-C3_MfaGFAP-C4_yrwg.ome.tiff')

# %%
img.shape
# Out:
# (5, 224063, 119668)

# %%
show_image(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_222788\238717493.py in <module>
# ----> 1 show_image(img)
#
# ~\AppData\Local\Temp\ipykernel_222788\2916180275.py in show_image(img, **kwargs)
#       5     for a,t,u in zip(ax.ravel(),[1,2,4,8,16,32,64,128],[16,8,4,2,1,1,1,1]):
#       6         sl = tuple(slice(c - s//t//2, c + s//t//2, u) for s,c in zip(img.shape[:2],mid))
# ----> 7         a.imshow(img[sl], **kwargs)
#       8         a.axis('off')
#       9     plt.tight_layout()
#
# ~\Anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
# ...

# %%
my_model = StarDist2D(None, name='NeunPosCellColor', basedir='C:/Users/ya-chen.chuang/Documents/QuPath/models')
# Out:
# Loading network weights from 'weights_best.h5'.
# Loading thresholds from 'thresholds.json'.
# Using default values: prob_thresh=0.500924, nms_thresh=0.3.

# %%
from csbdeep.data import Normalizer, normalize_mi_ma

class MyNormalizer(Normalizer):
    def __init__(self, mi, ma):
            self.mi, self.ma = mi, ma
    def before(self, x, axes):
        return normalize_mi_ma(x, self.mi, self.ma, dtype=np.float32)
    def after(*args, **kwargs):
        assert False
    @property
    def do_after(self):
        return False

# mi, ma = np.percentile(img[::8], [1,99.8])                      # compute percentiles from low-resolution image
# mi, ma = np.percentile(img[13000:16000,13000:16000], [1,99.8])  # compute percentiles from smaller crop
mi, ma = 0, 255                                                   # use min and max dtype values (suitable here)
normalizer = MyNormalizer(mi, ma)

# %%
help(my_model.predict_instances_big)
# Out:
# Help on method predict_instances_big in module stardist.models.base:
#
# predict_instances_big(img, axes, block_size, min_overlap, context=None, labels_out=None, labels_out_dtype=<class 'numpy.int32'>, show_progress=True, **kwargs) method of stardist.models.model2d.StarDist2D instance
#     Predict instance segmentation from very large input images.
#
#     Intended to be used when `predict_instances` cannot be used due to memory limitations.
#     This function will break the input image into blocks and process them individually
#     via `predict_instances` and assemble all the partial results. If used as intended, the result
#     should be the same as if `predict_instances` was used directly on the whole image.
#
#     **Important**: The crucial assumption is that all predicted object instances are smaller than
#                    the provided `min_overlap`. Also, it must hold that: min_overlap + 2*context < block_size.
#
#     Example
#     -------
#     >>> img.shape
# ...

# %%
#Slow - takes time to segment the large image
labels, polys = my_model.predict_instances_big(img, axes='YXC', block_size=1024, min_overlap=128, context=128,
                                            normalizer=normalizer, n_tiles=(4,4,1))
# Out:
# effective: block_size=(1024, 1024, 3), min_overlap=(128, 128, 0), context=(128, 128, 0)
# ...
# 100%|██████████| 20/20 [00:50<00:00,  2.55s/it]

# %%
show_image(labels, cmap=cmap)

# %%
fig, (a,b) = plt.subplots(1,2, figsize=(16,16))
a.imshow(labels[::8,::8], cmap='tab20b')
b.imshow(labels[::8,::8], cmap=cmap)
a.axis('off'); b.axis('off');
None;

# %%
from skimage.measure import regionprops_table
import pandas as pd

# %%
# Slow - takes time as we have many many objects
props = regionprops_table(labels, img, 
                          properties=['label',
                                      'area', 'equivalent_diameter',
                                      'mean_intensity', 'solidity'])

# %%
analysis_results = pd.DataFrame(props)
print(analysis_results.tail())
# Out:
#      label   area  equivalent_diameter  mean_intensity-0  mean_intensity-1  \
# 212    213  19828           158.889250          0.119578          0.119578
# 213    214  12895           128.134398          1.759984          1.759984
# 214    215  12897           128.144334          0.024812          0.024812
# 215    216  16891           146.650227          0.233497          0.233497
# 216    217   7887           100.209981          0.033346          0.033346
#
#      mean_intensity-2  solidity
# 212         13.513920  0.900086
# 213         16.221946  0.990399
# 214         16.450647  0.761694
# 215          7.482209  0.943368
# 216         22.626981  0.885682

# %%
import seaborn as sns

# %%
sns.histplot(x="area", data=analysis_results, bins=50, log_scale=True)
# Out:
# <AxesSubplot:xlabel='area', ylabel='Count'>
